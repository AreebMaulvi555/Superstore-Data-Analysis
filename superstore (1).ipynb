# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("sample.csv", encoding="latin-1")

# %%
df.groupby("Sales")[["Ship Mode","Category"]]

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
x=df.groupby(["Ship Mode","Category"]).sum().loc["First Class"]
x
# Out:
#                   Row ID  Postal Code        Sales  Quantity  Discount  \
# Category
# Furniture        1669054     18296355  110730.5229      1238     58.87
# Office Supplies  4392355     48774925  101332.3090      3372    154.00
# Technology       1437126     17158231  139365.5910      1083     40.30
#
#                      Profit
# Category
# Furniture         3066.9474
# Office Supplies  18400.3291
# Technology       27502.5634

# %%
x_=["Furniture","Office Supplies","Technology"]
y_=x["Sales"]
y_=y_.to_list()
y_
# Out:
# [110730.5229, 101332.309, 139365.59100000001]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x_,y_)
plt.xlabel("First-Class Data")
# Out:
# Text(0.5, 0, 'First-Class Data')

# %%
x.index.to_list()
# Out:
# ['Furniture', 'Office Supplies', 'Technology']

# %%
df.groupby(["Ship Mode","Category"]).sum()
# Out:
#                                   Row ID  Postal Code        Sales  Quantity  \
# Ship Mode      Category
# First Class    Furniture         1669054     18296355  110730.5229      1238
#                Office Supplies   4392355     48774925  101332.3090      3372
#                Technology        1437126     17158231  139365.5910      1083
# Same Day       Furniture          596736      6875573   39148.7790       453
#                Office Supplies   1690911     18967793   29090.4810      1147
#                Technology         497351      5398727   60123.8650       360
# Second Class   Furniture         2117274     23518842  156289.0244      1569
#                Office Supplies   5763479     63821635  160683.0030      4480
#                Technology        1721244     20852111  142221.5420      1374
# Standard Class Furniture         6310262     69505256  435831.4690      4768
#                Office Supplies  18163790    199208519  427941.2390     13907
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
x_cat=df.groupby("Category").sum()[["Sales","Profit"]]
x_cat
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.groupby("Segment").mean()
# Out:
#                   Row ID   Postal Code       Sales  Quantity  Discount  \
# Segment
# Consumer     4928.015604  55649.895781  223.733644  3.760547  0.158141
# Corporate    5134.017881  54482.228477  233.823300  3.843709  0.158228
# Home Office  4968.565339  55051.998317  240.972041  3.782389  0.147128
#
#                 Profit
# Segment
# Consumer     25.836873
# Corporate    30.456667
# Home Office  33.818664

# %%
df.groupby("Segment").sum()
# Out:
#                Row ID  Postal Code         Sales  Quantity  Discount  \
# Segment
# Consumer     25581329    288878609  1.161401e+06     19521    820.91
# Corporate    15504734    164536330  7.061464e+05     11608    477.85
# Home Office   8858952     98157713  4.296531e+05      6744    262.33
#
#                   Profit
# Segment
# Consumer     134119.2092
# Corporate     91979.1340
# Home Office   60298.6785

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
from datetime import datetime
from dateutil import relativedelta
datetime.strptime(df["Order Date"],"%d/%m/%Y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6264\2422873665.py in <module>
#       1 from datetime import datetime
#       2 from dateutil import relativedelta
# ----> 3 datetime.strptime(df["Order Date"],"%d/%m/%Y")
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
df["Ship Mode"].value_counts()

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# Calculate difference in days
df["Shipping Delay"] = (df["Ship Date"] - df["Order Date"]).dt.days
df["Shipping Delay"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country         9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9994 non-null   int64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %%
df.groupby("Ship Mode").mean()
# Out:
#                      Row ID   Postal Code       Sales  Quantity  Discount  \
# Ship Mode
# First Class     4875.510403  54765.611834  228.497024  3.701560  0.164610
# Same Day        5128.909761  57536.082873  236.396179  3.609576  0.152394
# Second Class    4936.759383  55626.009254  236.089239  3.816452  0.138895
# Standard Class  5036.776977  54944.447051  227.583067  3.819873  0.160023
#
#                    Profit  Shipping Delay
# Ship Mode
# First Class     31.839948        2.182705
# Same Day        29.266591        0.044199
# Second Class    29.535545        3.238046
# Standard Class  27.494770        5.006535

# %%
df.groupby("City")["Sales"].sum().idxmax()
# Out:
# 'New York City'

# %%
df.groupby("City")["Sales"].sum().nlargest(1)
# Out:
# City
# New York City    256368.161
# Name: Sales, dtype: float64

# %%
df["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df.groupby("Sub-Category")["Discount"].mean().nlargest(1)
# Out:
# Sub-Category
# Binders    0.372292
# Name: Discount, dtype: float64

# %%
x=df["Discount"]
y=df["Profit"]
x
y
plt.scatter(x,y)

# %%
np.corrcoef(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6264\1987999452.py in <module>
# ----> 1 np.corrcoef(x,y)
#
# NameError: name 'np' is not defined

# %%
df[["Sales", "Profit"]].corr()
# Out:
#            Sales    Profit
# Sales   1.000000  0.479064
# Profit  0.479064  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df.groupby("Region").sum()
# Out:
#            Row ID  Postal Code        Sales  Quantity  Discount       Profit  \
# Region
# Central  11685963    151786150  501239.8908      8780    558.34   39706.3625
# East     14073919     50171698  678781.2400     10618    414.00   91522.7800
# South     8213295     55875052  391721.9050      6209    238.55   46749.4303
# West     15971838    293739752  725457.8245     12266    350.20  108418.4489
#
#          Shipping Delay
# Region
# Central            9427
# East              11132
# South              6412
# West              12587

# %%
df["order_year"]=df["Order Date"].astype("str").str.split("-").str[0]

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df_order=df.groupby(["order_year","Region"])["Quantity"].sum()
df_order
# Out:
# order_year  Region
# 2014        Central    1726
#             East       1986
#             South      1336
#             West       2533
# 2015        Central    1815
#             East       2382
#             South      1344
#             West       2438
# 2016        Central    2359
#             East       2839
#             South      1614
#             West       3025
# 2017        Central    2880
#             East       3411
#             South      1915
#             West       4270
# Name: Quantity, dtype: int64

# %%
df.groupby("order_year").apply(lambda x: x.loc[x["Quantity"].idxmax(), ["Region", "Quantity"]])
# Out:
#              Region  Quantity
# order_year
# 2014           East        14
# 2015           West        14
# 2016           West        14
# 2017        Central        14

# %%
df.groupby(["order_year", "Region"])["Quantity"].sum().groupby("order_year").idxmax()
# Out:
# order_year
# 2014    (2014, West)
# 2015    (2015, West)
# 2016    (2016, West)
# 2017    (2017, West)
# Name: Quantity, dtype: object

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Delay', 'order_year'],
#       dtype='object')

# %%
df["Order Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country         9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9994 non-null   int64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %%
(df["Ship Date"] - df["Order Date"]).dt.days
# Out:
# 0       3
# 1       3
# 2       4
# 3       7
# 4       7
#        ..
# 9989    2
# 9990    5
# 9991    5
# 9992    5
# 9993    5
# Length: 9994, dtype: int64

# %%
df["order_months"]=df["Order Date"].astype("str").str.split("-").str[1]

# %%
months={1:"January",2:"February",3:"March",4:"April",5:"May",6:"June",7:"July",8:"August",9:"September",
       10:"October",11:"November",12:"December"}
months
# Out:
# {1: 'January',
#  2: 'February',
#  3: 'March',
#  4: 'April',
#  5: 'May',
#  6: 'June',
#  7: 'July',
#  8: 'August',
#  9: 'September',
#  10: 'October',
#  11: 'November',
#  12: 'December'}

# %%
df["order_months"]=df["Order Date"].astype("str").str.split("-").str[1]

# %%
df.groupby("order_months")["Quantity"].sum().idxmax()
# Out:
# '11'

# %%
import matplotlib.pyplot as plt

monthly_sales = df.groupby("order_months")["Quantity"].sum()
monthly_sales.plot(kind="bar", figsize=(10, 5), color="skyblue")

plt.title("Monthly Order Quantity Trend")
plt.xlabel("Month")
plt.ylabel("Total Quantity Sold")
plt.xticks(rotation=0)
plt.show()

# %%
df["Return_of_investment"]=df["Profit"]/df["Sales"]

# %%
df.groupby("City")["Return_of_investment"].sum().idxmax()
# Out:
# 'New York City'

# %%
df["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Delay', 'order_year', 'order_months', 'Return_of_investment'],
#       dtype='object')

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df.groupby("Segment").sum()
# Out:
#                Row ID  Postal Code         Sales  Quantity  Discount  \
# Segment
# Consumer     25581329    288878609  1.161401e+06     19521    820.91
# Corporate    15504734    164536330  7.061464e+05     11608    477.85
# Home Office   8858952     98157713  4.296531e+05      6744    262.33
#
#                   Profit  Shipping Delay  Return_of_investment
# Segment
# Consumer     134119.2092           20462            581.649065
# Corporate     91979.1340           12103            366.031878
# Home Office   60298.6785            6993            254.736470

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.groupby("Segment")[["Sales","Profit","Return_of_investment"]].agg(["sum","mean"])
# Out:
#                     Sales                   Profit             \
#                       sum        mean          sum       mean
# Segment
# Consumer     1.161401e+06  223.733644  134119.2092  25.836873
# Corporate    7.061464e+05  233.823300   91979.1340  30.456667
# Home Office  4.296531e+05  240.972041   60298.6785  33.818664
#
#             Return_of_investment
#                              sum      mean
# Segment
# Consumer              581.649065  0.112050
# Corporate             366.031878  0.121203
# Home Office           254.736470  0.142870

# %%
df.groupby("Segment").sum()
# Out:
#                Row ID  Postal Code         Sales  Quantity  Discount  \
# Segment
# Consumer     25581329    288878609  1.161401e+06     19521    820.91
# Corporate    15504734    164536330  7.061464e+05     11608    477.85
# Home Office   8858952     98157713  4.296531e+05      6744    262.33
#
#                   Profit  Shipping Delay  Return_of_investment
# Segment
# Consumer     134119.2092           20462            581.649065
# Corporate     91979.1340           12103            366.031878
# Home Office   60298.6785            6993            254.736470

# %%
result = df.groupby('Segment').agg({
    'Sales': ['sum', 'mean', 'max'],     # Total, Average, and Max Sales
    'Profit': ['sum', 'mean'],           # Total and Average Profit
    'Discount': ['mean', 'count']        # Average Discount and Count of Orders
})

# Display result
print(result)
# Out:
#                     Sales                             Profit             \
#                       sum        mean       max          sum       mean
# Segment
# Consumer     1.161401e+06  223.733644  13999.96  134119.2092  25.836873
# Corporate    7.061464e+05  233.823300  17499.95   91979.1340  30.456667
# Home Office  4.296531e+05  240.972041  22638.48   60298.6785  33.818664
#
#              Discount
#                  mean count
# Segment
# Consumer     0.158141  5191
# Corporate    0.158228  3020
# Home Office  0.147128  1783

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df.groupby(["order_year","Sub-Category"]).sum()
# Out:
#                           Row ID  Postal Code        Sales  Quantity  \
# order_year Sub-Category
# 2014       Accessories    763406      8903209   25014.2720       580
#            Appliances     488382      4859680   15313.6250       314
#            Art            763740      9351732    6057.9820       613
#            Binders       1510362     15532982   43488.2650      1089
#            Bookcases      199546      2159926   20036.6776       153
# ...                          ...          ...          ...       ...
# 2017       Paper         2356710     25101605   27694.7180      1702
#            Phones        1465307     15658068  105340.5160      1090
#            Storage       1446110     16707119   69677.6180      1022
#            Supplies       326365      3169876   16049.4100       192
#            Tables         553440      6340602   60893.5425       390
#
#                          Discount      Profit  Shipping Delay  \
# order_year Sub-Category
# ...

# %%
df_order=df.groupby(["order_year", "Sub-Category"])["Sales"].agg(["max", "min"]).reset_index()
df_order[df_order["order_year"]=="2014"]
# Out:
#    order_year Sub-Category        max      min
# 0        2014  Accessories   1687.800    1.980
# 1        2014   Appliances   1737.180    2.394
# 2        2014          Art   1113.024    1.344
# 3        2014      Binders   9449.950    0.852
# 4        2014    Bookcases   4007.840   61.960
# 5        2014       Chairs   3785.292   37.296
# 6        2014      Copiers   1999.960  479.984
# 7        2014    Envelopes    604.656    1.632
# 8        2014    Fasteners     49.792    1.984
# 9        2014  Furnishings    821.880    3.480
# 10       2014       Labels    491.550    2.520
# 11       2014     Machines  22638.480   29.925
# 12       2014        Paper    733.950    3.380
# 13       2014       Phones   4548.810    5.940
# 14       2014      Storage   2934.330    8.940
# 15       2014     Supplies   8187.650    2.920
# 16       2014       Tables   3610.848   53.316

# %%
df.groupby(['order_months',"Sub-Category"]).sum()
# Out:
#                            Row ID  Postal Code       Sales  Quantity  \
# order_months Sub-Category
# 01           Accessories   136418      1710129   5477.9060       111
#              Appliances     70593       606552   3176.2440        40
#              Art           210702      2119098    914.3700       131
#              Binders       315108      3442500  12214.2010       244
#              Bookcases      62834       832716   5352.3586        48
# ...                           ...          ...         ...       ...
# 12           Paper         990211     11601443  11250.1220       740
#              Phones        517398      6717701  38816.9020       410
#              Storage       585293      7306242  30642.9680       397
#              Supplies      142023      1395841   4401.9960        89
#              Tables        238099      2966197  39193.2580       206
#
#                            Discount     Profit  Shipping Delay  \
# order_months Sub-Category
# ...

# %%
df.groupby(["Sub-Category", "order_months"])["Sales"].sum().groupby("Sub-Category").pct_change() * 100
# Out:
# Sub-Category  order_months
# Accessories   01                    NaN
#               02              -1.983057
#               03              63.274117
#               04              -9.295810
#               05              20.893524
#                                 ...
# Tables        08              66.188365
#               09              16.204710
#               10               3.041917
#               11              64.083369
#               12              18.114328
# Name: Sales, Length: 203, dtype: float64

# %%
df.groupby(["Sub-Category", "order_months"])["Sales"].sum().groupby("Sub-Category").sum()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
df[df["Sub-Category"]=="Accessories"].sum()["Sales"]
# Out:
# C:\Users\Areeb\AppData\Local\Temp\ipykernel_6264\2772930522.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["Sub-Category"]=="Accessories"].sum()["Sales"]
# 167380.31800000003

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df.groupby(["order_year","Ship Mode"])["Shipping Delay"].mean()
# Out:
# order_year  Ship Mode
# 2014        First Class       2.250859
#             Same Day          0.022222
#             Second Class      3.230971
#             Standard Class    4.937449
# 2015        First Class       2.250000
#             Same Day          0.036697
#             Second Class      3.299760
#             Standard Class    4.975932
# 2016        First Class       2.126615
#             Same Day          0.031646
#             Second Class      3.177551
#             Standard Class    5.048325
# 2017        First Class       2.152098
#             Same Day          0.069892
#             Second Class      3.248097
#             Standard Class    5.037955
# Name: Shipping Delay, dtype: float64

# %%
df["Avg_Yearly_Delay"] = df.groupby("order_year")["Shipping Delay"].transform("mean")

df_filtered = df[df["Shipping Delay"] > 2 * df["Avg_Yearly_Delay"]]

# %%
df["Avg_Yearly_Delay"].nlargest(10)
# Out:
# 3     4.013796
# 4     4.013796
# 14    4.013796
# 15    4.013796
# 24    4.013796
# 27    4.013796
# 28    4.013796
# 29    4.013796
# 30    4.013796
# 31    4.013796
# Name: Avg_Yearly_Delay, dtype: float64

# %%
df["Avg_Yearly_Delay_2"] = df.groupby("order_year")["Shipping Delay"].mean()

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.groupby("order_year")["Shipping Delay"].transform("mean")
# Out:
# 0       3.950522
# 1       3.950522
# 2       3.950522
# 3       4.013796
# 4       4.013796
#           ...
# 9989    3.996989
# 9990    3.905495
# 9991    3.905495
# 9992    3.905495
# 9993    3.905495
# Name: Shipping Delay, Length: 9994, dtype: float64

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])  # Ensure it's in datetime format
df = df.sort_values("Order Date")  # Sort by date

df["7_Day_Rolling_Avg_Sales"] = df["Sales"].rolling(window=7).mean()

# %%
df3=df.reset_index()

# %%
df3.head(50)
# Out:
#     index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0    7980    7981  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
# 1     739     740  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 2     740     741  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 3     741     742  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 4    1759    1760  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# 5    7476    7477  CA-2014-167199 2014-01-06 2014-01-10  Standard Class
# 6    7474    7475  CA-2014-167199 2014-01-06 2014-01-10  Standard Class
# 7    7475    7476  CA-2014-167199 2014-01-06 2014-01-10  Standard Class
# 8    7180    7181  CA-2014-106054 2014-01-06 2014-01-07     First Class
# 9    7477    7478  CA-2014-167199 2014-01-06 2014-01-10  Standard Class
# 10   7478    7479  CA-2014-167199 2014-01-06 2014-01-10  Standard Class
# 11   7479    7480  CA-2014-167199 2014-01-06 2014-01-10  Standard Class
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df["Order Date"], df["Sales"], label="Daily Sales", alpha=0.5)
plt.plot(df["Order Date"], df["7_Day_Rolling_Avg_Sales"], label="7-Day Rolling Average", color="red")
plt.legend()
plt.show()

# %%
df.head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7980    7981  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
# 739      740  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 740      741  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 741      742  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 1759    1760  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
#
#      Customer ID  Customer Name      Segment        Country          City  \
# 7980    DP-13000  Darren Powers     Consumer  United States       Houston
# 739     PO-19195  Phillina Ober  Home Office  United States    Naperville
# 740     PO-19195  Phillina Ober  Home Office  United States    Naperville
# 741     PO-19195  Phillina Ober  Home Office  United States    Naperville
# 1759    MB-18085     Mick Brown     Consumer  United States  Philadelphia
#
#       ... Quantity  Discount   Profit Shipping Delay order_year order_months  \
# ...

# %%
customer_years = df.groupby("Customer Name")["order_year"].unique()

# Step 2: Identify customers who have orders in all four years (2014, 2015, 2016, 2017)
customers_all_years = customer_years[customer_years.apply(lambda x: set(["2014","2015","2016","2017"]).issubset(set(x)))]

# %%
customers_all_years
# Out:
# Customer Name
# Aaron Hawkins         [2014, 2015, 2016, 2017]
# Adam Hart             [2014, 2015, 2016, 2017]
# Adam Shillingsburg    [2014, 2015, 2016, 2017]
# Adrian Barton         [2014, 2015, 2016, 2017]
# Aimee Bixby           [2014, 2015, 2016, 2017]
#                                 ...
# Vivek Sundaresam      [2014, 2015, 2016, 2017]
# William Brown         [2014, 2015, 2016, 2017]
# Xylona Preis          [2014, 2015, 2016, 2017]
# Yoseph Carroll        [2014, 2015, 2016, 2017]
# Zuschuss Carroll      [2014, 2015, 2016, 2017]
# Name: order_year, Length: 306, dtype: object

# %%
customers_list = customers_all_years.index.tolist()
len(customers_list)
# Out:
# 306

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (Replace with your actual dataset)

# Step 1: Create a pivot table to track customer presence in each year
customer_year_matrix = df.pivot_table(index="Customer Name", columns="order_year", aggfunc="size", fill_value=0)

# Step 2: Convert to binary (1 if customer ordered in that year, else 0)
customer_year_matrix = (customer_year_matrix > 0).astype(int)

# Step 3: Compute total customers per year
total_customers = customer_year_matrix.sum()

# Step 4: Compute retained customers (customers appearing in previous and current year)
retention = customer_year_matrix.cumsum(axis=1)
retained_customers = (retention > 1).sum()

# Step 5: Plot retention over time
plt.figure(figsize=(8, 5))
plt.plot(total_customers.index, total_customers.values, marker="o", label="Total Customers", linestyle="--")
plt.plot(retained_customers.index, retained_customers.values, marker="s", label="Retained Customers", linestyle="-")

plt.xlabel("Year")
plt.ylabel("Number of Customers")
plt.title("Customer Retention Over Time (2014-2017)")
plt.legend()
plt.grid(True)
plt.show()

# %%
customer_year_matrix = df.pivot_table(index="Customer Name", columns="order_year", aggfunc="size", fill_value=0)
customer_year_matrix
# Out:
# order_year          2014  2015  2016  2017
# Customer Name
# Aaron Bergman          4     0     2     0
# Aaron Hawkins          7     2     1     1
# Aaron Smayling         1     0     2     7
# Adam Bellavance        0     1     9     8
# Adam Hart              1     1     6    12
# ...                  ...   ...   ...   ...
# Xylona Preis          10     3     9     6
# Yana Sorensen          0     5     0     7
# Yoseph Carroll         3     1     3     1
# Zuschuss Carroll       5     9     9     8
# Zuschuss Donatelli     3     0     5     1
#
# [793 rows x 4 columns]
